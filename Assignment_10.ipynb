# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %%
import shutil

copyTree = r"xyz\Python" # give folder path which you want to copy

copyTo = r"xyz\New folder2" # path and mention new folder name where you are going to copy.

shutil.copytree(copyTree, copyTo)

print("successfull")
# Out:
# successfull

# %%
import shutil
copyPath = r"xyz\sample.txt" # give file path which you want to copy

copyTo = r"xyz\new_random.txt" # path, in which file you are going to copy

shutil.copy(copyPath,copyTo)

print("Successfully copied")

# %% [markdown]
# 2. What function is used to rename files??
#
# Ans: shutil.move(oldname, new name)

# %% [markdown]
# 3. What is the difference between the delete functions in the send2trash and shutil modules?
#
# Ans:
#
# send2trash sends file or folder into recycle bin.
# shutil deletes file or folder permanently.

# %%
import shutil

shutil.rmtree(r"file or folder path")

# %%
import send2trash

send2trash.send2trash(r"file or folder path")

# %% [markdown]
# 4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
#
# Ans: open() method itself.

# %%
import zipfile

zipFolder = r"D:\FDS\New Text Document.zip"

with zipfile.ZipFile(zipFolder, "r") as archive:
    with archive.open("New Text Document.txt", "r") as file:
        matter = file.read()
        result  = matter.decode().splitlines()
        for resul in result:
            print(resul)
# Out:
# Deep within the jungle, a curious monkey named Milo embarked on an adventure.
# He discovered a hidden temple and met a wise owl who warned of ancient spirits.
# Undeterred, Milo braved treacherous paths, clever parrots, and shaky bridges.
# In the heart of the temple, he found a golden amulet with magical powers.
# The amulet granted him the ability to communicate with animals.
# Milo became the jungle's protector, ensuring harmony among its inhabitants.
# News of his heroism spread, making him a legendary figure.
# Milo's journey taught us the power of determination and courage.
# He proved that wonders await those who explore the unknown.
# And so, the jungle celebrated its fearless hero, forever grateful to Milo.

# %% [markdown]
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
import os
import shutil

sourcePath = "D:\FDS"
newFolder = "D:\FDS\BlueCrystal"
searchfiles = ".jpg"

def copy_files(srcpth,nwfldr,srchfls):
    for x, y, files in os.walk(srcpth):
        for f in files:
            if f.endswith(srchfls):
                source_path = os.path.join(x,f)
                dest_path = os.path.join(nwfldr,f)
                try:
                    shutil.copy(source_path, nwfldr)
                    print(f"copied successfully into {f}")
                except shutil.SameFileError:
                    print(f"Skipped{f} because it found as duplicate.")
                          
copy_files(sourcePath, newFolder, searchfiles)
# Out:
# Skipped2x2.jpg because it found as duplicate.
# Skippedchina.jpg because it found as duplicate.
# Skippedflower.jpg because it found as duplicate.
# Skippedgrace_hopper.jpg because it found as duplicate.
# Skippedjpg_0.jpg because it found as duplicate.
# Skippedjpg_1.jpg because it found as duplicate.
# Skippedjpg_10.jpg because it found as duplicate.
# Skippedjpg_100.jpg because it found as duplicate.
# Skippedjpg_101.jpg because it found as duplicate.
# Skippedjpg_102.jpg because it found as duplicate.
# Skippedjpg_103.jpg because it found as duplicate.
# Skippedjpg_104.jpg because it found as duplicate.
# Skippedjpg_105.jpg because it found as duplicate.
# Skippedjpg_106.jpg because it found as duplicate.
# Skippedjpg_107.jpg because it found as duplicate.
# Skippedjpg_108.jpg because it found as duplicate.
# Skippedjpg_109.jpg because it found as duplicate.
# Skippedjpg_11.jpg because it found as duplicate.
# Skippedjpg_110.jpg because it found as duplicate.
# ...
